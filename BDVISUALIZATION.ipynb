# %% [markdown]
# ## **DASHBOARDS FOR SPOTFIRE**

# %% [markdown]
# ![Picture1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Picture2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## **DASHBOARD FOR TABLEAU**

# %% [markdown]
# ![Picture3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## **POWER BI**

# %% [markdown]
# ![pwbi4.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![pwbi7.jpg](data:image/jpeg;base64,...)![pwbi5.jpg](data:image/jpeg;base64,...)![pwbi3.jpg](data:image/jpeg;base64,...)![pwbi2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## **DATAWRAPPER**

# %% [markdown]
# ![dw1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![dw2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![dw3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## **PLOTLY**

# %% [markdown]
# ![plt3.jpg](data:image/jpeg;base64,...)![plt4.jpg](data:image/jpeg;base64,...)![plt2.jpg](data:image/jpeg;base64,...)![plt1.jpg](data:image/jpeg;base64,...)![plt.jpg](data:image/jpeg;base64,...)
